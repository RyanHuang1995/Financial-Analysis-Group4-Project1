# %%
import pandas as pd
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)

# %%
import pandas_datareader.data as web

# %%
import matplotlib.pylab as plt

# %%
import scipy.stats as stats

# %%
from scipy.stats import ttest_ind

# %%
import matplotlib.pyplot as plt

# %%
import mpl_finance as mpl

# %%
import seaborn as seb

# %%
from mpl_finance import candlestick_ohlc

# %%
import matplotlib.dates as mdates

# %%
from matplotlib.dates import date2num

# %%
from matplotlib import style

# %%
# %matplotlib inline

# %%
import bs4 #beautifulsoup4

# %%
import sklearn #scikit_learn

# %%
import numpy as np

# %%
import datetime as dt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
from scipy.stats import ttest_ind

# %%
style.use('ggplot')

# %%
start_07 = dt.datetime(2007,1,1)

# %%
end_07 = dt.datetime(2007,12,31)

# %%
start_08 = dt.datetime(2008,1,1)

# %%
end_08 = dt.datetime(2008,12,31)

# %%
start_09 = dt.datetime(2009,1,1)

# %%
end_09 = dt.datetime(2009,12,31)

# %%
start_10 = dt.datetime(2010,1,1)

# %%
end_10 = dt.datetime(2010,12,31)

# %%
start_11 = dt.datetime(2011,1,1)

# %%
end_11 = dt.datetime(2011,12,31)

# %%
start_12 = dt.datetime(2012,1,1)

# %%
end_12 = dt.datetime(2012,12,31)

# %%
start_13 = dt.datetime(2013,1,1)

# %%
end_13 = dt.datetime(2013,12,31)

# %%
start_14 = dt.datetime(2014,1,1)

# %%
end_14 = dt.datetime(2014,12,31)

# %%
start_15 = dt.datetime(2015,1,1)

# %%
end_15 = dt.datetime(2015,12,31)

# %%
start_16 = dt.datetime(2016,1,1)

# %%
end_16 = dt.datetime(2016,12,31)

# %%
start_17 = dt.datetime(2017,1,1)

# %%
end_17 = dt.datetime(2017,12,31)

# %%
start_18 = dt.datetime(2018,1,1)

# %%
end_18 = dt.datetime(2018,12,31)

# %%
df_nvda_07 = web.DataReader('NVDA','quandl', start_07,end_07)

# %%
df_nvda_08 = web.DataReader('NVDA','quandl', start_08,end_08)

# %%
df_nvda_09 = web.DataReader('NVDA','quandl', start_09,end_09)

# %%
df_nvda_10 = web.DataReader('NVDA','quandl', start_10,end_10)

# %%
df_nvda_11 = web.DataReader('NVDA','quandl', start_11,end_11)

# %%
df_nvda_12 = web.DataReader('NVDA','quandl', start_12,end_12)

# %%
df_nvda_13 = web.DataReader('NVDA','quandl', start_13,end_13)

# %%
df_nvda_14 = web.DataReader('NVDA','quandl', start_14,end_14)

# %%
df_nvda_15 = web.DataReader('NVDA','quandl', start_15,end_15)

# %%
df_nvda_16 = web.DataReader('NVDA','quandl', start_16,end_16)

# %%
df_nvda_17 = web.DataReader('NVDA','quandl', start_17,end_17)

# %%
#---------------------------------------------------------------------------------------------------------------------------

# %%
df_amzn_07 = web.DataReader('AMZN','quandl', start_07,end_07)

# %%
df_amzn_07 = web.DataReader('AMZN','quandl', start_07,end_07)

# %%
df_amzn_08 = web.DataReader('AMZN','quandl', start_08,end_08)

# %%
df_amzn_09 = web.DataReader('AMZN','quandl', start_09,end_09)

# %%
df_amzn_10 = web.DataReader('AMZN','quandl', start_10,end_10)

# %%
df_amzn_11 = web.DataReader('AMZN','quandl', start_11,end_11)

# %%
df_amzn_12 = web.DataReader('AMZN','quandl', start_12,end_12)

# %%
df_amzn_13 = web.DataReader('AMZN','quandl', start_13,end_13)

# %%
df_amzn_14 = web.DataReader('AMZN','quandl', start_14,end_14)

# %%
df_amzn_15 = web.DataReader('AMZN','quandl', start_15,end_15)

# %%
df_amzn_16 = web.DataReader('AMZN','quandl', start_16,end_16)

# %%
df_amzn_17 = web.DataReader('AMZN','quandl', start_17,end_17)

# %%
plt.plot(df_nvda_07.index,df_nvda_07['AdjClose'], c='r')
plt.plot(df_amzn_07.index,df_amzn_07['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_08.index,df_nvda_08['AdjClose'], c='r')
plt.plot(df_amzn_08.index,df_amzn_08['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_09.index,df_nvda_09['AdjClose'], c='r')
plt.plot(df_amzn_09.index,df_amzn_09['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_10.index,df_nvda_10['AdjClose'], c='r')
plt.plot(df_amzn_10.index,df_amzn_10['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_11.index,df_nvda_11['AdjClose'], c='r')
plt.plot(df_amzn_11.index,df_amzn_11['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_12.index,df_nvda_12['AdjClose'], c='r')
plt.plot(df_amzn_12.index,df_amzn_12['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_13.index,df_nvda_13['AdjClose'], c='r')
plt.plot(df_amzn_13.index,df_amzn_13['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_14.index,df_nvda_14['AdjClose'], c='r')
plt.plot(df_amzn_14.index,df_amzn_14['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_15.index,df_nvda_15['AdjClose'], c='r')
plt.plot(df_amzn_15.index,df_amzn_15['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_16.index,df_nvda_16['AdjClose'], c='r')
plt.plot(df_amzn_16.index,df_amzn_16['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_nvda_17.index,df_nvda_17['AdjClose'], c='r')
plt.plot(df_amzn_17.index,df_amzn_17['AdjClose'], c='g')
plt.show()

# %%
df_nvda_07.head()
# Out:
#              Open   High    Low  Close     Volume  ExDividend  SplitRatio  \
# Date
# 2007-12-31  34.51  35.14  34.01  34.02  6905900.0         0.0         1.0
# 2007-12-28  35.08  35.50  34.49  34.79  6551600.0         0.0         1.0
# 2007-12-27  36.20  36.40  35.05  35.14  6034200.0         0.0         1.0
# 2007-12-26  35.85  36.26  35.50  36.26  5383500.0         0.0         1.0
# 2007-12-24  35.42  35.95  35.16  35.78  2600200.0         0.0         1.0
#
#               AdjOpen    AdjHigh     AdjLow   AdjClose  AdjVolume
# Date
# 2007-12-31  32.021818  32.606395  31.557868  31.567147  6905900.0
# 2007-12-28  32.550721  32.940439  32.003260  32.281630  6551600.0
# 2007-12-27  33.589968  33.775548  32.522884  32.606395  6034200.0
# 2007-12-26  33.265203  33.645642  32.940439  33.645642  5383500.0
# 2007-12-24  32.866207  33.357993  32.624953  33.200251  2600200.0

# %%
df_amzn_07.head()
# Out:
#              Open   High    Low  Close     Volume  ExDividend  SplitRatio  \
# Date
# 2007-12-31  93.81  94.37  92.45  92.64  5755200.0         0.0         1.0
# 2007-12-28  95.27  95.90  92.10  94.45  7587900.0         0.0         1.0
# 2007-12-27  92.67  95.29  92.50  94.25  7113700.0         0.0         1.0
# 2007-12-26  91.48  93.94  90.50  92.85  5442200.0         0.0         1.0
# 2007-12-24  91.05  91.56  90.30  91.01  2017100.0         0.0         1.0
#
#             AdjOpen  AdjHigh  AdjLow  AdjClose  AdjVolume
# Date
# 2007-12-31    93.81    94.37   92.45     92.64  5755200.0
# 2007-12-28    95.27    95.90   92.10     94.45  7587900.0
# 2007-12-27    92.67    95.29   92.50     94.25  7113700.0
# 2007-12-26    91.48    93.94   90.50     92.85  5442200.0
# 2007-12-24    91.05    91.56   90.30     91.01  2017100.0

# %%
df_nvda_07['Diff'] = df_nvda_07['AdjClose'] - df_nvda_07['AdjClose'].shift(1)
df_nvda_08['Diff'] = df_nvda_08['AdjClose'] - df_nvda_08['AdjClose'].shift(1)
df_nvda_09['Diff'] = df_nvda_09['AdjClose'] - df_nvda_09['AdjClose'].shift(1)
df_nvda_10['Diff'] = df_nvda_10['AdjClose'] - df_nvda_10['AdjClose'].shift(1)
df_nvda_11['Diff'] = df_nvda_11['AdjClose'] - df_nvda_11['AdjClose'].shift(1)
df_nvda_12['Diff'] = df_nvda_12['AdjClose'] - df_nvda_12['AdjClose'].shift(1)
df_nvda_13['Diff'] = df_nvda_13['AdjClose'] - df_nvda_13['AdjClose'].shift(1)
df_nvda_14['Diff'] = df_nvda_14['AdjClose'] - df_nvda_14['AdjClose'].shift(1)
df_nvda_15['Diff'] = df_nvda_15['AdjClose'] - df_nvda_15['AdjClose'].shift(1)
df_nvda_16['Diff'] = df_nvda_16['AdjClose'] - df_nvda_16['AdjClose'].shift(1)
df_nvda_17['Diff'] = df_nvda_17['AdjClose'] - df_nvda_17['AdjClose'].shift(1)
df_nvda_07.head()
# Out:
#              Open   High    Low  Close     Volume  ExDividend  SplitRatio  \
# Date
# 2007-12-31  34.51  35.14  34.01  34.02  6905900.0         0.0         1.0
# 2007-12-28  35.08  35.50  34.49  34.79  6551600.0         0.0         1.0
# 2007-12-27  36.20  36.40  35.05  35.14  6034200.0         0.0         1.0
# 2007-12-26  35.85  36.26  35.50  36.26  5383500.0         0.0         1.0
# 2007-12-24  35.42  35.95  35.16  35.78  2600200.0         0.0         1.0
#
#               AdjOpen    AdjHigh     AdjLow   AdjClose  AdjVolume      Diff
# Date
# 2007-12-31  32.021818  32.606395  31.557868  31.567147  6905900.0       NaN
# 2007-12-28  32.550721  32.940439  32.003260  32.281630  6551600.0  0.714483
# 2007-12-27  33.589968  33.775548  32.522884  32.606395  6034200.0  0.324765
# 2007-12-26  33.265203  33.645642  32.940439  33.645642  5383500.0  1.039248
# 2007-12-24  32.866207  33.357993  32.624953  33.200251  2600200.0 -0.445392

# %%
df_amzn_07['Diff'] = df_amzn_07['AdjClose'] - df_amzn_07['AdjClose'].shift(1)
df_amzn_08['Diff'] = df_amzn_08['AdjClose'] - df_amzn_08['AdjClose'].shift(1)
df_amzn_09['Diff'] = df_amzn_09['AdjClose'] - df_amzn_09['AdjClose'].shift(1)
df_amzn_10['Diff'] = df_amzn_10['AdjClose'] - df_amzn_10['AdjClose'].shift(1)
df_amzn_11['Diff'] = df_amzn_11['AdjClose'] - df_amzn_11['AdjClose'].shift(1)
df_amzn_12['Diff'] = df_amzn_12['AdjClose'] - df_amzn_12['AdjClose'].shift(1)
df_amzn_13['Diff'] = df_amzn_13['AdjClose'] - df_amzn_13['AdjClose'].shift(1)
df_amzn_14['Diff'] = df_amzn_14['AdjClose'] - df_amzn_14['AdjClose'].shift(1)
df_amzn_15['Diff'] = df_amzn_15['AdjClose'] - df_amzn_15['AdjClose'].shift(1)
df_amzn_16['Diff'] = df_amzn_16['AdjClose'] - df_amzn_16['AdjClose'].shift(1)
df_amzn_17['Diff'] = df_amzn_17['AdjClose'] - df_amzn_17['AdjClose'].shift(1)
df_amzn_07.head()
# Out:
#              Open   High    Low  Close     Volume  ExDividend  SplitRatio  \
# Date
# 2007-12-31  93.81  94.37  92.45  92.64  5755200.0         0.0         1.0
# 2007-12-28  95.27  95.90  92.10  94.45  7587900.0         0.0         1.0
# 2007-12-27  92.67  95.29  92.50  94.25  7113700.0         0.0         1.0
# 2007-12-26  91.48  93.94  90.50  92.85  5442200.0         0.0         1.0
# 2007-12-24  91.05  91.56  90.30  91.01  2017100.0         0.0         1.0
#
#             AdjOpen  AdjHigh  AdjLow  AdjClose  AdjVolume  Diff
# Date
# 2007-12-31    93.81    94.37   92.45     92.64  5755200.0   NaN
# 2007-12-28    95.27    95.90   92.10     94.45  7587900.0  1.81
# 2007-12-27    92.67    95.29   92.50     94.25  7113700.0 -0.20
# 2007-12-26    91.48    93.94   90.50     92.85  5442200.0 -1.40
# 2007-12-24    91.05    91.56   90.30     91.01  2017100.0 -1.84

# %%
df_amzn_17
# Out:
#                 Open       High        Low     Close      Volume  ExDividend  \
# Date
# 2017-12-29  1182.350  1184.0000  1167.5000  1169.470   2625283.0         0.0
# 2017-12-28  1189.000  1190.1000  1184.3800  1186.100   1803460.0         0.0
# 2017-12-27  1179.910  1187.2900  1175.6100  1182.260   1779382.0         0.0
# 2017-12-26  1168.360  1178.3200  1160.5500  1176.760   1964871.0         0.0
# 2017-12-22  1172.080  1174.6200  1167.8300  1168.360   1553997.0         0.0
# 2017-12-21  1175.900  1179.1700  1167.6400  1174.760   2042448.0         0.0
# 2017-12-20  1190.500  1191.0000  1176.0000  1177.620   2318916.0         0.0
# 2017-12-19  1189.150  1192.9700  1179.1400  1187.380   2555235.0         0.0
# 2017-12-18  1187.370  1194.7800  1180.9100  1190.580   2767271.0         0.0
# 2017-12-15  1179.030  1182.7500  1169.3300  1179.140   4539895.0         0.0
# 2017-12-14  1163.710  1177.9300  1162.4500  1174.260   3069993.0         0.0
# ...

# %%
df_nvda_17.drop(pd.to_datetime('2017-08-07'), inplace = True)
df_nvda_17
# Out:
#                Open      High       Low     Close      Volume  ExDividend  \
# Date
# 2017-12-29  198.460  198.4600  193.5000  193.5000   6896330.0        0.00
# 2017-12-28  198.130  199.3800  197.1514  197.4000   5978211.0        0.00
# 2017-12-27  196.900  199.9700  196.3100  197.1700   8097374.0        0.00
# 2017-12-26  193.030  197.7500  191.8200  197.4400   8821296.0        0.00
# 2017-12-22  194.400  195.6500  191.2500  195.2700  11613423.0        0.00
# 2017-12-21  196.940  197.9500  195.5500  195.8900   7458634.0        0.00
# 2017-12-20  197.700  198.0700  194.5500  196.8000   7185318.0        0.00
# 2017-12-19  197.520  197.7300  194.9600  196.1100   9217358.0        0.00
# 2017-12-18  193.200  198.0200  192.0000  197.9000  11730697.0        0.00
# 2017-12-15  188.251  192.3800  185.6200  191.5600  16090200.0        0.00
# 2017-12-14  185.920  189.3400  184.6000  186.4700  10871746.0        0.00
# 2017-12-13  192.500  192.5500  185.8800  186.1800  13744496.0        0.00
# ...

# %%
n_7_m = df_nvda_07['Diff'].max()
n_7_i = df_nvda_07['Diff'].idxmax()
n_8_m = df_nvda_08['Diff'].max()
n_8_i = df_nvda_08['Diff'].idxmax()
n_9_m = df_nvda_09['Diff'].max()
n_9_i = df_nvda_09['Diff'].idxmax()
n_10_m = df_nvda_10['Diff'].max()
n_10_i = df_nvda_10['Diff'].idxmax()
n_11_m = df_nvda_11['Diff'].max()
n_11_i = df_nvda_11['Diff'].idxmax()
n_12_m = df_nvda_12['Diff'].max()
n_12_i = df_nvda_12['Diff'].idxmax()
n_13_m = df_nvda_13['Diff'].max()
n_13_i = df_nvda_13['Diff'].idxmax()
n_14_m = df_nvda_14['Diff'].max()
n_14_i = df_nvda_14['Diff'].idxmax()
n_15_m = df_nvda_15['Diff'].max()
n_15_i = df_nvda_15['Diff'].idxmax()
n_16_m = df_nvda_16['Diff'].max()
n_16_i = df_nvda_16['Diff'].idxmax()
n_17_m = df_nvda_17['Diff'].max()
n_17_i = df_nvda_17['Diff'].idxmax()
nvda_max_index_data = {n_7_m:n_7_i, n_8_m:n_8_i, n_9_m:n_9_i, n_10_m:n_10_i, n_11_m:n_11_i, n_12_m:n_12_i, n_13_m:n_13_i, n_14_m:n_14_i, n_15_m:n_15_i,n_16_m:n_16_i, n_17_m:n_17_i}
for i in nvda_max_index_data:
    print (i,nvda_max_index_data[i])
y = nvda_max_index_data.keys()
x = nvda_max_index_data.values()
plt.plot(x,y)

plt.title('Largest price gain per year Nvidia')
plt.xlabel('Date')
plt.ylabel('Single Day Price Gain')

plt.savefig("Largest price gain per year Nvidia")
# Out:
# 3.089905929999997 2007-11-09 00:00:00
# 5.140564219879998 2008-07-02 00:00:00
# 1.3732915244442996 2009-05-07 00:00:00
# 1.5681504569669986 2010-05-13 00:00:00
# 2.2455172224020004 2011-02-18 00:00:00
# 0.7005642574020001 2012-10-18 00:00:00
# 0.4910580384180001 2013-05-21 00:00:00
# 1.0302030984250017 2014-10-09 00:00:00
# 1.6236032058810004 2015-05-07 00:00:00
# 8.0445938095 2016-12-27 00:00:00
# 14.29000000000002 2017-11-28 00:00:00

# %%
a_7_m = df_amzn_07['Diff'].max()
a_7_i = df_amzn_07['Diff'].idxmax()
a_8_m = df_amzn_08['Diff'].max()
a_8_i = df_amzn_08['Diff'].idxmax()
a_9_m = df_amzn_09['Diff'].max()
a_9_i = df_amzn_09['Diff'].idxmax()
a_10_m = df_amzn_10['Diff'].max()
a_10_i = df_amzn_10['Diff'].idxmax()
a_11_m = df_amzn_11['Diff'].max()
a_11_i = df_amzn_11['Diff'].idxmax()
a_12_m = df_amzn_12['Diff'].max()
a_12_i = df_amzn_12['Diff'].idxmax()
a_13_m = df_amzn_13['Diff'].max()
a_13_i = df_amzn_13['Diff'].idxmax()
a_14_m = df_amzn_14['Diff'].max()
a_14_i = df_amzn_14['Diff'].idxmax()
a_15_m = df_amzn_15['Diff'].max()
a_15_i = df_amzn_15['Diff'].idxmax()
a_16_m = df_amzn_16['Diff'].max()
a_16_i = df_amzn_16['Diff'].idxmax()
a_17_m = df_amzn_17['Diff'].max()
a_17_i = df_amzn_17['Diff'].idxmax()
amzn_max_index_data = {a_7_m:a_7_i, a_8_m:a_8_i, a_9_m:a_9_i, a_10_m:a_10_i, a_11_m:a_11_i, a_12_m:a_12_i, a_13_m:a_13_i, a_14_m:a_14_i, a_15_m:a_15_i, a_16_m:a_16_i, a_17_m:a_17_i}
for i in amzn_max_index_data:
    print (i,amzn_max_index_data[i])
y = amzn_max_index_data.keys()
x = amzn_max_index_data.values()
plt.plot(x,y)
plt.title('Largest price gain per year Amazon')
plt.xlabel('Date')
plt.ylabel('Single Day Price Gain')

plt.savefig("Largest price gain per year Amazon")
# Out:
# 12.08999999999999 2007-10-23 00:00:00
# 7.350000000000001 2008-09-26 00:00:00
# 7.38000000000001 2009-07-23 00:00:00
# 9.189999999999998 2010-06-28 00:00:00
# 28.75 2011-10-25 00:00:00
# 14.97999999999999 2012-01-31 00:00:00
# 19.889999999999986 2013-04-25 00:00:00
# 44.31999999999999 2014-01-30 00:00:00
# 31.100000000000023 2015-08-21 00:00:00
# 48.35000000000002 2016-01-28 00:00:00
# 32.32999999999993 2017-11-28 00:00:00

# %%
df_07_cor = df_nvda_07.corrwith(df_amzn_07['AdjClose'])
df_07_cor
# Out:
# Open          0.451098
# High          0.452436
# Low           0.439614
# Close         0.448859
# Volume       -0.120555
# ExDividend         NaN
# SplitRatio    0.058984
# AdjOpen       0.915560
# AdjHigh       0.917132
# AdjLow        0.921016
# AdjClose      0.919830
# AdjVolume    -0.447852
# Diff         -0.025595
# dtype: float64

# %%
df_08_corr = df_nvda_08.corrwith(df_amzn_08['AdjClose'])
df_08_corr.to_frame()
# Out:
#                    0
# Open        0.672312
# High        0.670680
# Low         0.678393
# Close       0.674576
# Volume      0.230833
# ExDividend       NaN
# SplitRatio       NaN
# AdjOpen     0.672312
# AdjHigh     0.670680
# AdjLow      0.678393
# AdjClose    0.674576
# AdjVolume   0.230833
# Diff        0.087467

# %%
df_nvda_09.corrwith(df_amzn_09['AdjClose'])
# Out:
# Open          0.755462
# High          0.752782
# Low           0.759892
# Close         0.754838
# Volume       -0.187947
# ExDividend         NaN
# SplitRatio         NaN
# AdjOpen       0.755462
# AdjHigh       0.752782
# AdjLow        0.759892
# AdjClose      0.754838
# AdjVolume    -0.187947
# Diff         -0.064572
# dtype: float64

# %%
df_10_corr = df_nvda_10.corrwith(df_amzn_10['AdjClose'])
df_10_corr.to_frame()
# Out:
#                    0
# Open        0.007391
# High        0.005800
# Low         0.029307
# Close       0.021766
# Volume     -0.158918
# ExDividend       NaN
# SplitRatio       NaN
# AdjOpen     0.007391
# AdjHigh     0.005800
# AdjLow      0.029307
# AdjClose    0.021766
# AdjVolume  -0.158918
# Diff       -0.109772

# %%
df_nvda_11.corrwith(df_amzn_11['AdjClose'])
# Out:
# Open         -0.527465
# High         -0.524326
# Low          -0.523466
# Close        -0.516962
# Volume       -0.168867
# ExDividend         NaN
# SplitRatio         NaN
# AdjOpen      -0.527465
# AdjHigh      -0.524326
# AdjLow       -0.523466
# AdjClose     -0.516962
# AdjVolume    -0.168867
# Diff          0.053241
# dtype: float64

# %%
df_12_corr=df_nvda_12.corrwith(df_amzn_12['AdjClose'])
df_12_corr.to_frame()
# Out:
#                                           0
# Open                              -0.589421
# High                              -0.596952
# Low                               -0.578786
# Close                             -0.583234
# Volume                            -0.269418
# ExDividend                         0.032917
# SplitRatio                              NaN
# AdjOpen                           -0.585582
# AdjHigh                           -0.593225
# AdjLow                            -0.574605
# AdjClose                          -0.579167
# AdjVolume                         -0.269418
# Diff                               0.012288
# Nvidia Average Close Differential  0.012288

# %%
df_nvda_13.corrwith(df_amzn_13['AdjClose'])
# Out:
# Open          0.727294
# High          0.719565
# Low           0.723644
# Close         0.722976
# Volume       -0.277890
# ExDividend   -0.002164
# SplitRatio         NaN
# AdjOpen       0.740901
# AdjHigh       0.733981
# AdjLow        0.737324
# AdjClose      0.737032
# AdjVolume    -0.277890
# Diff          0.024017
# dtype: float64

# %%
df_nvda_14.corrwith(df_amzn_14['AdjClose'])
# Out:
# Open         -0.562371
# High         -0.573556
# Low          -0.550905
# Close        -0.556563
# Volume        0.104665
# ExDividend   -0.010377
# SplitRatio         NaN
# AdjOpen      -0.572407
# AdjHigh      -0.583276
# AdjLow       -0.561684
# AdjClose     -0.567371
# AdjVolume     0.104665
# Diff          0.066516
# dtype: float64

# %%
df_nvda_15.corrwith(df_amzn_15['AdjClose'])
# Out:
# Open          0.845033
# High          0.847956
# Low           0.844153
# Close         0.845463
# Volume        0.128241
# ExDividend    0.037281
# SplitRatio         NaN
# AdjOpen       0.852739
# AdjHigh       0.855483
# AdjLow        0.851888
# AdjClose      0.853153
# AdjVolume     0.128241
# Diff         -0.076901
# dtype: float64

# %%
df_nvda_16.corrwith(df_amzn_16['AdjClose'])
# Out:
# Open          0.767641
# High          0.761952
# Low           0.774202
# Close         0.767600
# Volume        0.102276
# ExDividend    0.006090
# SplitRatio         NaN
# AdjOpen       0.767782
# AdjHigh       0.762123
# AdjLow        0.774306
# AdjClose      0.767737
# AdjVolume     0.102276
# Diff         -0.054180
# dtype: float64

# %%
df_nvda_17.corrwith(df_amzn_17['AdjClose'])
# Out:
# Open          0.860379
# High          0.861974
# Low           0.860593
# Close         0.861463
# Volume       -0.116379
# ExDividend   -0.041520
# SplitRatio         NaN
# AdjOpen       0.860556
# AdjHigh       0.862150
# AdjLow        0.860756
# AdjClose      0.861632
# AdjVolume    -0.116379
# Diff          0.037645
# dtype: float64

# %%
df_nvda_07_AdjClose = df_nvda_07['AdjClose']
df_nvda_07_AdjClose.head()
# Out:
# Date
# 2007-12-31    31.567147
# 2007-12-28    32.281630
# 2007-12-27    32.606395
# 2007-12-26    33.645642
# 2007-12-24    33.200251
# Name: AdjClose, dtype: float64

# %%
df_amzn_07_AdjClose = df_amzn_07['AdjClose']
df_amzn_07_AdjClose.head()
# Out:
# Date
# 2007-12-31    92.64
# 2007-12-28    94.45
# 2007-12-27    94.25
# 2007-12-26    92.85
# 2007-12-24    91.01
# Name: AdjClose, dtype: float64

# %%
df_nvda_07_AdjClose.rename(index='Date')
df_nvda_07_AdjClose.to_frame()
df_nvda_07_AdjClose.head()
# Out:
# Date
# 2007-12-31    31.567147
# 2007-12-28    32.281630
# 2007-12-27    32.606395
# 2007-12-26    33.645642
# 2007-12-24    33.200251
# Name: AdjClose, dtype: float64

# %%
df_amzn_07_AdjClose.rename(index='Date')
df_nvda_07_AdjClose.head()
# Out:
# Date
# 2007-12-31    31.567147
# 2007-12-28    32.281630
# 2007-12-27    32.606395
# 2007-12-26    33.645642
# 2007-12-24    33.200251
# Name: AdjClose, dtype: float64

# %%
merged_07 = pd.concat([df_nvda_07_AdjClose, df_amzn_07_AdjClose], axis=1, join_axes=[df_nvda_07_AdjClose.index])
merged_07.columns = ['NVDA_07', 'AMZN_07']
merged_07.head()
# Out:
#               NVDA_07  AMZN_07
# Date
# 2007-12-31  31.567147    92.64
# 2007-12-28  32.281630    94.45
# 2007-12-27  32.606395    94.25
# 2007-12-26  33.645642    92.85
# 2007-12-24  33.200251    91.01

# %%
correlation = merged_07.corr()
correlation
# Out:
#          NVDA_07  AMZN_07
# NVDA_07  1.00000  0.91983
# AMZN_07  0.91983  1.00000

# %%
plt.scatter(df_nvda_07['Diff'], df_amzn_07['Diff'], marker = 'x', c='g')
plt.xlabel = ('nvidia price change per day')
plt.ylabel = ('Amazon price change per day')

# %%
seb.regplot(df_nvda_07['Diff'], df_amzn_07['Diff'], marker = 'x')
plt.title('07 Regression')
# Out:
# Text(0.5,1,'07 Regression')

# %%
seb.regplot(df_nvda_08['Diff'], df_amzn_08['Diff'], marker = 'x')

# %%
seb.regplot(df_nvda_09['Diff'], df_amzn_09['Diff'], marker = 'x')

# %%
seb.regplot(df_nvda_10['Diff'], df_amzn_10['Diff'], marker = 'x')

# %%
seb.regplot(df_nvda_11['Diff'], df_amzn_11['Diff'], marker = 'x')

# %%
df_nvda_12['Nvidia Average Close Differential']=df_nvda_12['Diff']
df_amzn_12['Amazon Average Close Differential']=df_amzn_12['Diff']
plt.title('NVDA & AMZN 12')
seb.regplot(df_nvda_12['Nvidia Average Close Differential'], df_amzn_12['Amazon Average Close Differential'], marker = 'x')
plt.savefig('Lowest regression NA')

# %%
seb.regplot(df_nvda_13['Diff'], df_amzn_13['Diff'], marker = 'x')

# %%
seb.regplot(df_nvda_14['Diff'], df_amzn_14['Diff'], marker = 'x')

# %%
seb.regplot(df_nvda_15['Diff'], df_amzn_15['Diff'], marker = 'x')

# %%
seb.regplot(df_nvda_16['Diff'], df_amzn_16['Diff'], marker = 'x')

# %%
plt.title('NVDA & AMZN 17')
df_nvda_17['Nvidia Average Close Differential']=df_nvda_17['Diff']
df_amzn_17['Amazon Average Close Differential']=df_amzn_17['Diff']
seb.regplot(df_nvda_17['Nvidia Average Close Differential'], df_amzn_17['Amazon Average Close Differential'], marker = 'x')
plt.savefig('Highest regression NA')

# %%
df_amzn_07.loc[:,"Diff"].std()
# Out:
# 2.22840165000274

# %%
df_amzn_08.loc[:,"Diff"].std()
# Out:
# 2.662796568185435

# %%
df_amzn_09.loc[:,"Diff"].std()
# Out:
# 2.6870420421184105

# %%
df_amzn_10.loc[:,"Diff"].std()
# Out:
# 2.8308213323828446

# %%
df_amzn_11.loc[:,"Diff"].std()
# Out:
# 4.896848599247502

# %%
df_amzn_12.loc[:,"Diff"].std()
# Out:
# 4.222548058589742

# %%
df_amzn_13.loc[:,"Diff"].std()
# Out:
# 5.0630558618954415

# %%
df_amzn_14.loc[:,"Diff"].std()
# Out:
# 6.9724934906367695

# %%
df_amzn_15.loc[:,"Diff"].std()
# Out:
# 9.630835550625255

# %%
df_amzn_16.loc[:,"Diff"].std()
# Out:
# 11.89406599619795

# %%
df_amzn_17.loc[:,"Diff"].std()
# Out:
# 12.955299261960656

# %%
df_nvda_07.loc[:,"Diff"].std()
# Out:
# 0.8069421479673909

# %%
df_nvda_08.loc[:,"Diff"].std()
# Out:
# 0.7885184230393739

# %%
df_nvda_09.loc[:,"Diff"].std()
# Out:
# 0.37779907558745185

# %%
df_nvda_10.loc[:,"Diff"].std()
# Out:
# 0.3384215389524245

# %%
df_nvda_11.loc[:,"Diff"].std()
# Out:
# 0.5867936481805075

# %%
df_nvda_12.loc[:,"Diff"].std()
# Out:
# 0.24813736203065026

# %%
df_nvda_13.loc[:,"Diff"].std()
# Out:
# 0.17976421402316395

# %%
df_nvda_14.loc[:,"Diff"].std()
# Out:
# 0.27954291049205204

# %%
df_nvda_15.loc[:,"Diff"].std()
# Out:
# 0.5063617660090465

# %%
df_nvda_16.loc[:,"Diff"].std()
# Out:
# 1.897607372063242

# %%
df_nvda_17.loc[:,"Diff"].std()
# Out:
# 3.6388188588395307

# %%
df_amzn_07.loc[:,"Diff"].cov(df_nvda_07.loc[:,"Diff"])
# Out:
# 0.5428223488151516

# %%
df_amzn_08.loc[:,"Diff"].cov(df_nvda_08.loc[:,"Diff"])
# Out:
# 0.7048153155451818

# %%
df_amzn_09.loc[:,"Diff"].cov(df_nvda_09.loc[:,"Diff"])
# Out:
# 0.2648622392667409

# %%
df_amzn_10.loc[:,"Diff"].cov(df_nvda_10.loc[:,"Diff"])
# Out:
# 0.35935413681482503

# %%
df_amzn_11.loc[:,"Diff"].cov(df_nvda_11.loc[:,"Diff"])
# Out:
# 1.0099520899479633

# %%
df_amzn_12.loc[:,"Diff"].cov(df_nvda_12.loc[:,"Diff"])
# Out:
# 0.23102550967347388

# %%
df_amzn_13.loc[:,"Diff"].cov(df_nvda_13.loc[:,"Diff"])
# Out:
# 0.24857435606000872

# %%
df_amzn_14.loc[:,"Diff"].cov(df_nvda_14.loc[:,"Diff"])
# Out:
# 0.6832421785890502

# %%
df_amzn_15.loc[:,"Diff"].cov(df_nvda_15.loc[:,"Diff"])
# Out:
# 1.1536262258413776

# %%
df_amzn_16.loc[:,"Diff"].cov(df_nvda_16.loc[:,"Diff"])
# Out:
# 4.991573875469221

# %%
df_amzn_17.loc[:,"Diff"].cov(df_nvda_17.loc[:,"Diff"])
# Out:
# 17.359630266032784

# %%
df_nvda_07['Diff'].mean()
# Out:
# -0.036992267189988014

# %%
df_amzn_07['Diff'].mean()
# Out:
# -0.21575999999999998

# %%
nvda_07_mean=df_nvda_07['Diff'].mean()
nvda_07_mean
# Out:
# -0.036992267189988014

# %%
nvda_08_mean = df_nvda_08['Diff'].mean()
nvda_08_mean
# Out:
# 0.09183261105652578

# %%
nvda_09_mean = df_nvda_09['Diff'].mean()
nvda_09_mean
# Out:
# -0.03685721034432749

# %%
nvda_10_mean = df_nvda_10['Diff'].mean()
nvda_10_mean
# Out:
# 0.011423147438713149

# %%
nvda_11_mean = df_nvda_11['Diff'].mean()
nvda_11_mean
# Out:
# 0.007245750478924301

# %%
nvda_12_mean = df_nvda_12['Diff'].mean()
nvda_12_mean
# Out:
# 0.006334960749429721

# %%
nvda_13_mean = df_nvda_13['Diff'].mean()
nvda_13_mean
# Out:
# -0.013577831599649407

# %%
nvda_14_mean = df_nvda_14['Diff'].mean()
nvda_14_mean
# Out:
# -0.01729887386208765

# %%
nvda_15_mean = df_nvda_15['Diff'].mean()
nvda_15_mean
# Out:
# -0.051754295178745004

# %%
nvda_16_mean = df_nvda_16['Diff'].mean()
nvda_16_mean
# Out:
# -0.2965784941197011

# %%
nvda_17_mean = df_nvda_17['Diff'].mean()
nvda_17_mean
# Out:
# -0.37806238777399187

# %%
amzn_07_mean=df_amzn_07['Diff'].mean()
amzn_07_mean
# Out:
# -0.21575999999999998

# %%
amzn_08_mean=df_amzn_08['Diff'].mean()
amzn_08_mean
# Out:
# 0.17845238095238095

# %%
amzn_09_mean=df_amzn_09['Diff'].mean()
amzn_09_mean
# Out:
# -0.31936254980079676

# %%
amzn_10_mean=df_amzn_10['Diff'].mean()
amzn_10_mean
# Out:
# -0.1836653386454183

# %%
amzn_11_mean=df_amzn_11['Diff'].mean()
amzn_11_mean
# Out:
# 0.044302788844621535

# %%
amzn_12_mean=df_amzn_12['Diff'].mean()
amzn_12_mean
# Out:
# -0.2885140562248996

# %%
amzn_13_mean=df_amzn_13['Diff'].mean()
amzn_13_mean
# Out:
# -0.5636653386454183

# %%
amzn_14_mean=df_amzn_14['Diff'].mean()
amzn_14_mean
# Out:
# 0.34908366533864543

# %%
amzn_15_mean=df_amzn_15['Diff'].mean()
amzn_15_mean
# Out:
# -1.4636254980079682

# %%
amzn_16_mean=df_amzn_16['Diff'].mean()
amzn_16_mean
# Out:
# -0.4497211155378486

# %%
amzn_17_mean=df_amzn_17['Diff'].mean()
amzn_17_mean
# Out:
# -1.6766129032258068

# %%
def gendata_07(loc1=0, loc2=0):
    population_n_07 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_07 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_07, population_a_07
population_n_07, population_a_07 = gendata_07(loc1=nvda_07_mean, loc2=amzn_07_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_07)), population_n_07, label="NVDA 07")
plt.scatter(range(len(population_a_07)), population_a_07, label="AMZN 07")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_07, 10, density=True, alpha=0.5, label="NVDA 07")
plt.hist(population_a_07, 10, density=True, alpha=0.5, label="AMZN 07")
plt.axvline(population_n_07.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_07.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_07, population_a_07, equal_var=False)
# Out:
# Ttest_indResult(statistic=1.9545312545347666, pvalue=0.051197580796782556)

# %%
def gendata_08(loc1=0, loc2=0):
    population_n_08 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_08 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_08, population_a_08
population_n_08, population_a_08 = gendata_08(loc1=nvda_08_mean, loc2=amzn_08_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_08)), population_n_08, label="NVDA 08")
plt.scatter(range(len(population_a_08)), population_a_08, label="AMZN 08")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_08, 10, density=True, alpha=0.5, label="NVDA 08")
plt.hist(population_a_08, 10, density=True, alpha=0.5, label="AMZN 08")
plt.axvline(population_n_08.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_08.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_08, population_a_08, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.9470447762627602, pvalue=0.3440752628324226)

# %%
def gendata_09(loc1=0, loc2=0):
    population_n_09 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_09 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_09, population_a_09
population_n_09, population_a_09 = gendata_09(loc1=nvda_09_mean, loc2=amzn_09_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_09)), population_n_09, label="population1")
plt.scatter(range(len(population_a_09)), population_a_09, label="population2")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_09, 10, density=True, alpha=0.5, label="population1")
plt.hist(population_a_09, 10, density=True, alpha=0.5, label="population2")
plt.axvline(population_n_09.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_09.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_09, population_a_09, equal_var=False)
# Out:
# Ttest_indResult(statistic=3.0887314330234594, pvalue=0.0021223843706237766)

# %%
def gendata_10(loc1=0, loc2=0):
    population_n_10 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_10 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_10, population_a_10
population_n_10, population_a_10 = gendata_10(loc1=nvda_10_mean, loc2=amzn_10_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_10)), population_n_10, label="population1")
plt.scatter(range(len(population_a_10)), population_a_10, label="population2")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_10, 10, density=True, alpha=0.5, label="population1")
plt.hist(population_a_10, 10, density=True, alpha=0.5, label="population2")
plt.axvline(population_n_10.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_10.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_10, population_a_10, equal_var=False)
# Out:
# Ttest_indResult(statistic=2.132971859393357, pvalue=0.03341534539978136)

# %%
def gendata_11(loc1=0, loc2=0):
    population_n_11 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_11 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_11, population_a_11
population_n_11, population_a_11 = gendata_11(loc1=nvda_11_mean, loc2=amzn_11_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_11)), population_n_11, label="Nvidia 11")
plt.scatter(range(len(population_a_11)), population_a_11, label="Amazon 11")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_11, 10, density=True, alpha=0.5, label="Nvidia 11")
plt.hist(population_a_11, 10, density=True, alpha=0.5, label="Amazon 11")
plt.axvline(population_n_11.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_11.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend() 
plt.savefig('NA Histogram 11')

# %%
stats.ttest_ind(population_n_11, population_a_11, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.40515779076990566, pvalue=0.6855355151683209)

# %%
def gendata_12(loc1=0, loc2=0):
    population_n_12 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_12 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_12, population_a_12
population_n_12, population_a_12 = gendata_12(loc1=nvda_12_mean, loc2=amzn_12_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_12)), population_n_12, label="population1")
plt.scatter(range(len(population_a_12)), population_a_12, label="population2")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_12, 10, density=True, alpha=0.5, label="population1")
plt.hist(population_a_12, 10, density=True, alpha=0.5, label="population2")
plt.axvline(population_n_12.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_12.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_12, population_a_12, equal_var=False)
# Out:
# Ttest_indResult(statistic=3.2236892530132444, pvalue=0.001348504929710313)

# %%
def gendata_13(loc1=0, loc2=0):
    population_n_13 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_13 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_13, population_a_13
population_n_13, population_a_13 = gendata_13(loc1=nvda_13_mean, loc2=amzn_13_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_13)), population_n_13, label="population1")
plt.scatter(range(len(population_a_13)), population_a_13, label="population2")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_13, 10, density=True, alpha=0.5, label="population1")
plt.hist(population_a_13, 10, density=True, alpha=0.5, label="population2")
plt.axvline(population_n_13.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_13.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_13, population_a_13, equal_var=False)
# Out:
# Ttest_indResult(statistic=6.014302516174522, pvalue=3.5000274858599025e-09)

# %%
def gendata_14(loc1=0, loc2=0):
    population_n_14 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_14 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_14, population_a_14
population_n_14, population_a_14 = gendata_14(loc1=nvda_14_mean, loc2=amzn_14_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_14)), population_n_14, label="population1")
plt.scatter(range(len(population_a_14)), population_a_14, label="population2")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_14, 10, density=True, alpha=0.5, label="population1")
plt.hist(population_a_14, 10, density=True, alpha=0.5, label="population2")
plt.axvline(population_n_14.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_14.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_14, population_a_14, equal_var=False)
# Out:
# Ttest_indResult(statistic=-4.005790713611022, pvalue=7.124644103329119e-05)

# %%
def gendata_15(loc1=0, loc2=0):
    population_n_15 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_15 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_15, population_a_15
population_n_15, population_a_15 = gendata_15(loc1=nvda_15_mean, loc2=amzn_15_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_15)), population_n_15, label="Nvidia 15")
plt.scatter(range(len(population_a_15)), population_a_15, label="Amazon 15")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_15, 10, density=True, alpha=0.5, label="Nvidia 15")
plt.hist(population_a_15, 10, density=True, alpha=0.5, label="Amazon 15")
plt.axvline(population_n_15.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_15.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend() 
plt.savefig('NA Histogram 15')

# %%
stats.ttest_ind(population_n_15, population_a_15, equal_var=False)
# Out:
# Ttest_indResult(statistic=15.436490410940442, pvalue=3.2502326479835394e-44)

# %%
def gendata_16(loc1=0, loc2=0):
    population_n_16 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_16 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_16, population_a_16
population_n_16, population_a_16 = gendata_16(loc1=nvda_16_mean, loc2=amzn_16_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_16)), population_n_16, label="population1")
plt.scatter(range(len(population_a_16)), population_a_16, label="population2")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_16, 10, density=True, alpha=0.5, label="population1")
plt.hist(population_a_16, 10, density=True, alpha=0.5, label="population2")
plt.axvline(population_n_16.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_16.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_16, population_a_16, equal_var=False)
# Out:
# Ttest_indResult(statistic=1.674362790522513, pvalue=0.09468716951836548)

# %%
def gendata_17(loc1=0, loc2=0):
    population_n_17 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_17 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_17, population_a_17
population_n_17, population_a_17 = gendata_17(loc1=nvda_17_mean, loc2=amzn_17_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_17)), population_n_17, label="population1")
plt.scatter(range(len(population_a_17)), population_a_17, label="population2")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_17, 10, density=True, alpha=0.5, label="population1")
plt.hist(population_a_17, 10, density=True, alpha=0.5, label="population2")
plt.axvline(population_n_17.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_17.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_17, population_a_17, equal_var=False)
# Out:
# Ttest_indResult(statistic=14.197514999757606, pvalue=1.1706343935017956e-38)

# %%
critical_value = stats.chi2.ppf(q = 0.95, df = 249)
critical_value
# Out:
# 286.807794444232

# %%
stats.chisquare(df_nvda_07['Diff'],)
# Out:
# D:\ANACONDA\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# D:\ANACONDA\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# D:\ANACONDA\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# Power_divergenceResult(statistic=nan, pvalue=nan)

# %%
data1 = pd.DataFrame(df_nvda_07['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_nvda_08['Diff']).assign(Location=2)
data3 = pd.DataFrame(df_nvda_09['Diff']).assign(Location=3)



cdf = pd.concat([data1, data2, data3])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.714483
# 2         1   Diff  0.324765
# 3         1   Diff  1.039248
# 4         1   Diff -0.445392

# %%
data4 = pd.DataFrame(df_nvda_10['Diff']).assign(Location=4)
data5 = pd.DataFrame(df_nvda_11['Diff']).assign(Location=5)
data6 = pd.DataFrame(df_nvda_12['Diff']).assign(Location=6)

cdf = pd.concat([data4, data5, data6])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         4   Diff       NaN
# 1         4   Diff -0.380439
# 2         4   Diff -0.046395
# 3         4   Diff  0.000000
# 4         4   Diff  0.055674

# %%
data7 = pd.DataFrame(df_nvda_13['Diff']).assign(Location=7)
data8 = pd.DataFrame(df_nvda_14['Diff']).assign(Location=8)
data9 = pd.DataFrame(df_nvda_15['Diff']).assign(Location=9)

cdf = pd.concat([data7, data8, data9])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         7   Diff       NaN
# 1         7   Diff -0.047715
# 2         7   Diff -0.200404
# 3         7   Diff -0.085887
# 4         7   Diff  0.143146

# %%
data10 = pd.DataFrame(df_nvda_16['Diff']).assign(Location=10)
data11 = pd.DataFrame(df_nvda_17['Diff']).assign(Location=11)


cdf = pd.concat([data10, data11])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0        10   Diff       NaN
# 1        10   Diff  4.675235
# 2        10   Diff -2.173137
# 3        10   Diff  8.044594
# 4        10   Diff -7.516262

# %%
data1 = pd.DataFrame(df_amzn_07['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_08['Diff']).assign(Location=2)
data3 = pd.DataFrame(df_amzn_09['Diff']).assign(Location=3)



cdf = pd.concat([data1, data2, data3])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter  value
# 0         1   Diff    NaN
# 1         1   Diff   1.81
# 2         1   Diff  -0.20
# 3         1   Diff  -1.40
# 4         1   Diff  -1.84

# %%
data4 = pd.DataFrame(df_amzn_10['Diff']).assign(Location=4)
data5 = pd.DataFrame(df_amzn_11['Diff']).assign(Location=5)
data6 = pd.DataFrame(df_amzn_12['Diff']).assign(Location=6)

cdf = pd.concat([data4, data5, data6])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter  value
# 0         4   Diff    NaN
# 1         4   Diff   2.75
# 2         4   Diff   0.62
# 3         4   Diff  -2.28
# 4         4   Diff   1.05

# %%
data7 = pd.DataFrame(df_amzn_13['Diff']).assign(Location=7)
data8 = pd.DataFrame(df_amzn_14['Diff']).assign(Location=8)
data9 = pd.DataFrame(df_amzn_15['Diff']).assign(Location=9)

cdf = pd.concat([data7, data8, data9])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter  value
# 0         7   Diff    NaN
# 1         7   Diff  -5.42
# 2         7   Diff   4.71
# 3         7   Diff   6.31
# 4         7   Diff  -5.19

# %%
data10 = pd.DataFrame(df_amzn_16['Diff']).assign(Location=10)
data11 = pd.DataFrame(df_amzn_17['Diff']).assign(Location=11)


cdf = pd.concat([data10, data11])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter  value
# 0        10   Diff    NaN
# 1        10   Diff  15.28
# 2        10   Diff   6.98
# 3        10   Diff  -0.73
# 4        10   Diff -10.81

# %%
#==================================================================================

# %%
data1 = pd.DataFrame(df_nvda_07['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_07['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.714483
# 2         1   Diff  0.324765
# 3         1   Diff  1.039248
# 4         1   Diff -0.445392

# %%
data1 = pd.DataFrame(df_nvda_08['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_08['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff -0.046395
# 2         1   Diff -0.250533
# 3         1   Diff -0.222696
# 4         1   Diff  0.194859

# %%
data1 = pd.DataFrame(df_nvda_09['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_09['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff -0.009279
# 2         1   Diff -0.603135
# 3         1   Diff -0.204138
# 4         1   Diff  0.269091

# %%
data1 = pd.DataFrame(df_nvda_10['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_10['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff -0.380439
# 2         1   Diff -0.046395
# 3         1   Diff  0.000000
# 4         1   Diff  0.055674

# %%
data1 = pd.DataFrame(df_nvda_11['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_11['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.102069
# 2         1   Diff -0.241254
# 3         1   Diff  0.324765
# 4         1   Diff  0.102069

# %%
data1 = pd.DataFrame(df_nvda_12['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_12['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff -0.149433
# 2         1   Diff  0.056037
# 3         1   Diff  0.074717
# 4         1   Diff  0.009340

# %%
data1 = pd.DataFrame(df_nvda_12['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_12['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff -0.149433
# 2         1   Diff  0.056037
# 3         1   Diff  0.074717
# 4         1   Diff  0.009340

# %%
data1 = pd.DataFrame(df_nvda_13['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_13['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff -0.047715
# 2         1   Diff -0.200404
# 3         1   Diff -0.085887
# 4         1   Diff  0.143146

# %%
data1 = pd.DataFrame(df_nvda_14['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_14['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.310860
# 2         1   Diff  0.184573
# 3         1   Diff  0.029143
# 4         1   Diff -0.019429

# %%
data1 = pd.DataFrame(df_nvda_15['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_15['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.424590
# 2         1   Diff  0.286352
# 3         1   Diff -0.533206
# 4         1   Diff  0.029623

# %%
data1 = pd.DataFrame(df_nvda_16['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_16['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  4.675235
# 2         1   Diff -2.173137
# 3         1   Diff  8.044594
# 4         1   Diff -7.516262

# %%
data1 = pd.DataFrame(df_nvda_17['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_amzn_17['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter  value
# 0         1   Diff    NaN
# 1         1   Diff   3.90
# 2         1   Diff  -0.23
# 3         1   Diff   0.27
# 4         1   Diff  -2.17
