# %%
import pandas as pd
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)

# %%
import pandas_datareader.data as web

# %%
import matplotlib.pyplot as plt

# %%
import scipy.stats as stats

# %%
from scipy.stats import ttest_ind

# %%
import mpl_finance as mpl

# %%
import seaborn as seb

# %%
from mpl_finance import candlestick_ohlc

# %%
import matplotlib.dates as mdates

# %%
from matplotlib.dates import date2num

# %%
from matplotlib import style

# %%
# %matplotlib inline

# %%
import bs4 #beautifulsoup4

# %%
import sklearn #scikit_learn

# %%
import numpy as np

# %%
import datetime as dt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
from scipy.stats import ttest_ind

# %%
style.use('ggplot')

# %%
start_07 = dt.datetime(2007,1,1)
end_07 = dt.datetime(2007,12,31)

# %%
start_08 = dt.datetime(2008,1,1)

# %%
end_08 = dt.datetime(2008,12,31)

# %%
start_09 = dt.datetime(2009,1,1)

# %%
end_09 = dt.datetime(2009,12,31)

# %%
start_10 = dt.datetime(2010,1,1)

# %%
end_10 = dt.datetime(2010,12,31)

# %%
start_11 = dt.datetime(2011,1,1)

# %%
end_11 = dt.datetime(2011,12,31)

# %%
start_12 = dt.datetime(2012,1,1)

# %%
end_12 = dt.datetime(2012,12,31)

# %%
start_13 = dt.datetime(2013,1,1)

# %%
end_13 = dt.datetime(2013,12,31)

# %%
start_14 = dt.datetime(2014,1,1)

# %%
end_14 = dt.datetime(2014,12,31)

# %%
start_15 = dt.datetime(2015,1,1)

# %%
end_15 = dt.datetime(2015,12,31)

# %%
start_16 = dt.datetime(2016,1,1)

# %%
end_16 = dt.datetime(2016,12,31)

# %%
start_17 = dt.datetime(2017,1,1)

# %%
end_17 = dt.datetime(2017,12,31)

# %%
start_18 = dt.datetime(2018,1,1)

# %%
end_18 = dt.datetime(2018,12,31)

# %%
df_aapl_07 = web.DataReader('AAPL','quandl', start_07,end_07)

# %%
df_aapl_08 = web.DataReader('AAPL','quandl', start_08,end_08)

# %%
df_aapl_09 = web.DataReader('AAPL','quandl', start_09,end_09)

# %%
df_aapl_10 = web.DataReader('AAPL','quandl', start_10,end_10)

# %%
df_aapl_11 = web.DataReader('AAPL','quandl', start_11,end_11)

# %%
df_aapl_12 = web.DataReader('AAPL','quandl', start_12,end_12)

# %%
df_aapl_13 = web.DataReader('AAPL','quandl', start_13,end_13)

# %%
df_aapl_14 = web.DataReader('AAPL','quandl', start_14,end_14)

# %%
df_aapl_15 = web.DataReader('AAPL','quandl', start_15,end_15)

# %%
df_aapl_16 = web.DataReader('AAPL','quandl', start_16,end_16)

# %%
df_aapl_17 = web.DataReader('AAPL','quandl', start_17,end_17)

# %%
#---------------------------------------------------------------------------------------------------------------------------

# %%
df_msft_07 = web.DataReader('MSFT','quandl', start_07,end_07)

# %%
df_msft_08 = web.DataReader('MSFT','quandl', start_08,end_08)

# %%
df_msft_09 = web.DataReader('MSFT','quandl', start_09,end_09)

# %%
df_msft_10 = web.DataReader('MSFT','quandl', start_10,end_10)

# %%
df_msft_11 = web.DataReader('MSFT','quandl', start_11,end_11)

# %%
df_msft_12 = web.DataReader('MSFT','quandl', start_12,end_12)

# %%
df_msft_13 = web.DataReader('MSFT','quandl', start_13,end_13)

# %%
df_msft_14 = web.DataReader('MSFT','quandl', start_14,end_14)

# %%
df_msft_15 = web.DataReader('MSFT','quandl', start_15,end_15)

# %%
df_msft_16 = web.DataReader('MSFT','quandl', start_16,end_16)

# %%
df_msft_17 = web.DataReader('MSFT','quandl', start_17,end_17)

# %%
plt.plot(df_aapl_07.index,df_aapl_07['AdjClose'], c='r')
plt.plot(df_msft_07.index,df_msft_07['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_08.index,df_aapl_08['AdjClose'], c='r')
plt.plot(df_msft_08.index,df_msft_08['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_09.index,df_aapl_09['AdjClose'], c='r')
plt.plot(df_msft_09.index,df_msft_09['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_10.index,df_aapl_10['AdjClose'], c='r')
plt.plot(df_msft_10.index,df_msft_10['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_11.index,df_aapl_11['AdjClose'], c='r')
plt.plot(df_msft_11.index,df_msft_11['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_12.index,df_aapl_12['AdjClose'], c='r')
plt.plot(df_msft_12.index,df_msft_12['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_13.index,df_aapl_13['AdjClose'], c='r')
plt.plot(df_msft_13.index,df_msft_13['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_14.index,df_aapl_14['AdjClose'], c='r')
plt.plot(df_msft_14.index,df_msft_14['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_15.index,df_aapl_15['AdjClose'], c='r')
plt.plot(df_msft_15.index,df_msft_15['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_16.index,df_aapl_16['AdjClose'], c='r')
plt.plot(df_msft_16.index,df_msft_16['AdjClose'], c='g')
plt.show()

# %%
plt.plot(df_aapl_17.index,df_aapl_17['AdjClose'], c='r')
plt.plot(df_msft_17.index,df_msft_17['AdjClose'], c='g')
plt.show()

# %%
df_aapl_07.tail()
# Out:
#              Open   High    Low  Close       Volume  ExDividend  SplitRatio  \
# Date
# 2007-01-09  86.45  92.98  85.15  92.57  119617800.0         0.0         1.0
# 2007-01-08  85.96  86.53  85.28  85.47   28468100.0         0.0         1.0
# 2007-01-05  85.77  86.20  84.40  85.05   29812200.0         0.0         1.0
# 2007-01-04  84.05  85.95  83.82  85.66   30259300.0         0.0         1.0
# 2007-01-03  86.29  86.58  81.90  83.80   44225700.0         0.0         1.0
#
#               AdjOpen    AdjHigh     AdjLow   AdjClose    AdjVolume
# Date
# 2007-01-09  11.110030  11.949226  10.942962  11.896535  837324600.0
# 2007-01-08  11.047058  11.120311  10.959669  10.984086  199276700.0
# 2007-01-05  11.022640  11.077901  10.846576  10.930110  208685400.0
# 2007-01-04  10.801596  11.045773  10.772038  11.008504  211815100.0
# 2007-01-03  11.089468  11.126737  10.525291  10.769468  309579900.0

# %%
df_msft_07
# Out:
#                Open     High      Low    Close       Volume  ExDividend  \
# Date
# 2007-12-31  35.9000  35.9900  35.5200  35.6000   35229700.0        0.00
# 2007-12-28  36.1000  36.2300  35.6700  36.1200   33447200.0        0.00
# 2007-12-27  36.3500  36.5501  35.9400  35.9700   33311100.0        0.00
# 2007-12-26  36.4100  36.6400  36.2600  36.6100   30252400.0        0.00
# 2007-12-24  36.1300  36.7200  36.0500  36.5800   29622600.0        0.00
# 2007-12-21  35.9000  36.0625  35.7500  36.0600   83240500.0        0.00
# 2007-12-20  35.2900  35.7900  35.0800  35.5200   59345000.0        0.00
# 2007-12-19  34.6900  35.1400  34.3800  34.7900   58469100.0        0.00
# 2007-12-18  34.6400  35.0000  34.2100  34.7400   52791800.0        0.00
# 2007-12-17  35.0300  35.1300  34.3600  34.3900   58121200.0        0.00
# 2007-12-14  35.0500  35.8400  35.0100  35.3100   71126200.0        0.00
# 2007-12-13  34.4800  35.4500  34.2800  35.2200   73913200.0        0.00
# ...

# %%
df_aapl_07['Diff'] = df_aapl_07['AdjClose'] - df_aapl_07['AdjClose'].shift(1)
df_aapl_08['Diff'] = df_aapl_08['AdjClose'] - df_aapl_08['AdjClose'].shift(1)
df_aapl_09['Diff'] = df_aapl_09['AdjClose'] - df_aapl_09['AdjClose'].shift(1)
df_aapl_10['Diff'] = df_aapl_10['AdjClose'] - df_aapl_10['AdjClose'].shift(1)
df_aapl_11['Diff'] = df_aapl_11['AdjClose'] - df_aapl_11['AdjClose'].shift(1)
df_aapl_12['Diff'] = df_aapl_12['AdjClose'] - df_aapl_12['AdjClose'].shift(1)
df_aapl_13['Diff'] = df_aapl_13['AdjClose'] - df_aapl_13['AdjClose'].shift(1)
df_aapl_14['Diff'] = df_aapl_14['AdjClose'] - df_aapl_14['AdjClose'].shift(1)
df_aapl_15['Diff'] = df_aapl_15['AdjClose'] - df_aapl_15['AdjClose'].shift(1)
df_aapl_16['Diff'] = df_aapl_16['AdjClose'] - df_aapl_16['AdjClose'].shift(1)
df_aapl_17['Diff'] = df_aapl_17['AdjClose'] - df_aapl_17['AdjClose'].shift(1)
df_aapl_07.head()
# Out:
#               Open    High       Low   Close      Volume  ExDividend  \
# Date
# 2007-12-31  199.50  200.50  197.7500  198.08  19261900.0         0.0
# 2007-12-28  200.59  201.56  196.8801  199.83  24987400.0         0.0
# 2007-12-27  198.95  202.96  197.8000  198.57  28411700.0         0.0
# 2007-12-26  199.01  200.96  196.8200  198.95  25133300.0         0.0
# 2007-12-24  195.03  199.33  194.7900  198.80  17150100.0         0.0
#
#             SplitRatio    AdjOpen    AdjHigh     AdjLow   AdjClose  \
# Date
# 2007-12-31         1.0  25.638531  25.767044  25.413631  25.456041
# 2007-12-28         1.0  25.778611  25.903269  25.301837  25.680940
# 2007-12-27         1.0  25.567848  26.083189  25.420057  25.519013
# 2007-12-26         1.0  25.575559  25.826161  25.294113  25.567848
# 2007-12-24         1.0  25.064073  25.616683  25.033230  25.548571
#
#               AdjVolume      Diff
# Date
# 2007-12-31  134833300.0       NaN
# 2007-12-28  174911800.0  0.224899
# ...

# %%
df_msft_07['Diff'] = df_msft_07['AdjClose'] - df_msft_07['AdjClose'].shift(1)
df_msft_08['Diff'] = df_msft_08['AdjClose'] - df_msft_08['AdjClose'].shift(1)
df_msft_09['Diff'] = df_msft_09['AdjClose'] - df_msft_09['AdjClose'].shift(1)
df_msft_10['Diff'] = df_msft_10['AdjClose'] - df_msft_10['AdjClose'].shift(1)
df_msft_11['Diff'] = df_msft_11['AdjClose'] - df_msft_11['AdjClose'].shift(1)
df_msft_12['Diff'] = df_msft_12['AdjClose'] - df_msft_12['AdjClose'].shift(1)
df_msft_13['Diff'] = df_msft_13['AdjClose'] - df_msft_13['AdjClose'].shift(1)
df_msft_14['Diff'] = df_msft_14['AdjClose'] - df_msft_14['AdjClose'].shift(1)
df_msft_15['Diff'] = df_msft_15['AdjClose'] - df_msft_15['AdjClose'].shift(1)
df_msft_16['Diff'] = df_msft_16['AdjClose'] - df_msft_16['AdjClose'].shift(1)
df_msft_17['Diff'] = df_msft_17['AdjClose'] - df_msft_17['AdjClose'].shift(1)
df_msft_07.head()
# Out:
#              Open     High    Low  Close      Volume  ExDividend  SplitRatio  \
# Date
# 2007-12-31  35.90  35.9900  35.52  35.60  35229700.0         0.0         1.0
# 2007-12-28  36.10  36.2300  35.67  36.12  33447200.0         0.0         1.0
# 2007-12-27  36.35  36.5501  35.94  35.97  33311100.0         0.0         1.0
# 2007-12-26  36.41  36.6400  36.26  36.61  30252400.0         0.0         1.0
# 2007-12-24  36.13  36.7200  36.05  36.58  29622600.0         0.0         1.0
#
#               AdjOpen    AdjHigh     AdjLow   AdjClose   AdjVolume      Diff
# Date
# 2007-12-31  27.988417  28.058583  27.692161  27.754531  35229700.0       NaN
# 2007-12-28  28.144342  28.245692  27.809104  28.159934  33447200.0  0.405403
# 2007-12-27  28.339247  28.495249  28.019602  28.042991  33311100.0 -0.116943
# 2007-12-26  28.386024  28.565337  28.269081  28.541949  30252400.0  0.498958
# 2007-12-24  28.167730  28.627707  28.105360  28.518560  29622600.0 -0.023389

# %%
df_aapl_17
# Out:
#                 Open      High       Low     Close       Volume  ExDividend  \
# Date
# 2017-12-29  170.5200  170.5900  169.2200  169.2300   25643711.0        0.00
# 2017-12-28  171.0000  171.8500  170.4800  171.0800   15997739.0        0.00
# 2017-12-27  170.1000  170.7800  169.7100  170.6000   21672062.0        0.00
# 2017-12-26  170.8000  171.4700  169.6790  170.5700   32968167.0        0.00
# 2017-12-22  174.6800  175.4240  174.5000  175.0100   16052615.0        0.00
# 2017-12-21  174.1700  176.0200  174.1000  175.0100   20356826.0        0.00
# 2017-12-20  174.8700  175.4200  173.2500  174.3500   23000392.0        0.00
# 2017-12-19  175.0300  175.3900  174.0900  174.5400   27078872.0        0.00
# 2017-12-18  174.8800  177.2000  174.8600  176.4200   28831533.0        0.00
# 2017-12-15  173.6300  174.1700  172.4600  173.8700   37054632.0        0.00
# 2017-12-14  172.4000  173.1300  171.6500  172.2200   20219307.0        0.00
# ...

# %%
df_msft_17.drop(pd.to_datetime('2017-08-07'), inplace = True)
df_msft_17
# Out:
#               Open     High      Low   Close      Volume  ExDividend  \
# Date
# 2017-12-29  85.630  86.0500  85.5000  85.540  18162779.0        0.00
# 2017-12-28  85.900  85.9300  85.5500  85.720   9872795.0        0.00
# 2017-12-27  85.650  85.9800  85.2150  85.710  13000828.0        0.00
# 2017-12-26  85.310  85.5346  85.0300  85.400   9737412.0        0.00
# 2017-12-22  85.400  85.6300  84.9200  85.510  14033977.0        0.00
# 2017-12-21  86.050  86.1000  85.4000  85.500  16638402.0        0.00
# 2017-12-20  86.200  86.3000  84.7100  85.520  23425009.0        0.00
# 2017-12-19  86.350  86.3500  85.2700  85.830  23241979.0        0.00
# 2017-12-18  87.120  87.4999  86.2300  86.380  21551076.0        0.00
# 2017-12-15  85.260  87.0900  84.8800  86.850  52430167.0        0.00
# 2017-12-14  85.430  85.8739  84.5300  84.690  19080106.0        0.00
# 2017-12-13  85.740  86.0000  85.1700  85.350  21307911.0        0.00
# ...

# %%
df_aapl_07['Diff'].max()
# Out:
# 1.492046816123004

# %%
df_aapl_07['Diff'].idxmax()
# Out:
# Timestamp('2007-11-09 00:00:00')

# %%
df_msft_07['Diff'].max()
# Out:
# 0.926284269252001

# %%
df_msft_07['Diff'].idxmax()
# Out:
# Timestamp('2007-02-26 00:00:00')

# %%
n_7_m = df_aapl_07['Diff'].max()
n_7_i = df_aapl_07['Diff'].idxmax()
n_8_m = df_aapl_08['Diff'].max()
n_8_i = df_aapl_08['Diff'].idxmax()
n_9_m = df_aapl_09['Diff'].max()
n_9_i = df_aapl_09['Diff'].idxmax()
n_10_m = df_aapl_10['Diff'].max()
n_10_i = df_aapl_10['Diff'].idxmax()
n_11_m = df_aapl_11['Diff'].max()
n_11_i = df_aapl_11['Diff'].idxmax()
n_12_m = df_aapl_12['Diff'].max()
n_12_i = df_aapl_12['Diff'].idxmax()
n_13_m = df_aapl_13['Diff'].max()
n_13_i = df_aapl_13['Diff'].idxmax()
n_14_m = df_aapl_14['Diff'].max()
n_14_i = df_aapl_14['Diff'].idxmax()
n_15_m = df_aapl_15['Diff'].max()
n_15_i = df_aapl_15['Diff'].idxmax()
n_16_m = df_aapl_16['Diff'].max()
n_16_i = df_aapl_16['Diff'].idxmax()
n_17_m = df_aapl_17['Diff'].max()
n_17_i = df_aapl_17['Diff'].idxmax()
aapl_max_index_data = {n_7_m:n_7_i, n_8_m:n_8_i, n_9_m:n_9_i, n_10_m:n_10_i, n_11_m:n_11_i, n_12_m:n_12_i, n_13_m:n_13_i, n_14_m:n_14_i, n_15_m:n_15_i,n_16_m:n_16_i, n_17_m:n_17_i}
for i in aapl_max_index_data:
    print (i,aapl_max_index_data[i])
y = aapl_max_index_data.keys()
x = aapl_max_index_data.values()
plt.plot(x,y)

plt.title('Largest price gain per year Apple')
plt.xlabel('Date')
plt.ylabel('Single Day Price Gain')
plt.savefig("Largest price gain per year Apple")
# Out:
# 1.492046816123004 2007-11-09 00:00:00
# 2.9532502872100004 2008-09-26 00:00:00
# 1.0088344105570002 2009-10-29 00:00:00
# 1.5588740637009977 2010-06-28 00:00:00
# 3.035499207305989 2011-10-18 00:00:00
# 4.804879811891013 2012-12-04 00:00:00
# 8.23504355787 2013-01-23 00:00:00
# 5.848590068169997 2014-01-27 00:00:00
# 6.628260469329987 2015-08-20 00:00:00
# 6.3475968238060005 2016-01-26 00:00:00
# 5.985713277740018 2017-06-08 00:00:00

# %%
n_7_m = df_msft_07['Diff'].max()
n_7_i = df_msft_07['Diff'].idxmax()
n_8_m = df_msft_08['Diff'].max()
n_8_i = df_msft_08['Diff'].idxmax()
n_9_m = df_msft_09['Diff'].max()
n_9_i = df_msft_09['Diff'].idxmax()
n_10_m = df_msft_10['Diff'].max()
n_10_i = df_msft_10['Diff'].idxmax()
n_11_m = df_msft_11['Diff'].max()
n_11_i = df_msft_11['Diff'].idxmax()
n_12_m = df_msft_12['Diff'].max()
n_12_i = df_msft_12['Diff'].idxmax()
n_13_m = df_msft_13['Diff'].max()
n_13_i = df_msft_13['Diff'].idxmax()
n_14_m = df_msft_14['Diff'].max()
n_14_i = df_msft_14['Diff'].idxmax()
n_15_m = df_msft_15['Diff'].max()
n_15_i = df_msft_15['Diff'].idxmax()
n_16_m = df_msft_16['Diff'].max()
n_16_i = df_msft_16['Diff'].idxmax()
n_17_m = df_msft_17['Diff'].max()
n_17_i = df_msft_17['Diff'].idxmax()
msft_max_index_data = {n_7_m:n_7_i, n_8_m:n_8_i, n_9_m:n_9_i, n_10_m:n_10_i, n_11_m:n_11_i, n_12_m:n_12_i, n_13_m:n_13_i, n_14_m:n_14_i, n_15_m:n_15_i,n_16_m:n_16_i, n_17_m:n_17_i}
for i in msft_max_index_data:
    print (i,msft_max_index_data[i])
y = msft_max_index_data.keys()
x = msft_max_index_data.values()
plt.plot(x,y)

plt.title('Largest price gain per year Microsoft')
plt.xlabel('Date')
plt.ylabel('Single Day Price Gain')
plt.savefig("Largest price gain per year Microsoft")
# Out:
# 0.926284269252001 2007-02-26 00:00:00
# 1.8850404939919976 2008-09-26 00:00:00
# 1.802257067267 2009-01-21 00:00:00
# 0.9267709536399984 2010-05-19 00:00:00
# 1.1591251656560004 2011-08-09 00:00:00
# 0.7821760980000008 2012-11-12 00:00:00
# 3.592443939916997 2013-07-18 00:00:00
# 1.6763917514790023 2014-10-09 00:00:00
# 4.0322446197329995 2015-01-26 00:00:00
# 3.835714570905999 2016-04-21 00:00:00
# 3.180000000000007 2017-12-01 00:00:00

# %%
df_aapl_07.corrwith(df_msft_07['AdjClose'])
# Out:
# Open          0.760325
# High          0.761270
# Low           0.760652
# Close         0.761669
# Volume        0.091207
# ExDividend         NaN
# SplitRatio         NaN
# AdjOpen       0.760325
# AdjHigh       0.761270
# AdjLow        0.760652
# AdjClose      0.761669
# AdjVolume     0.091207
# Diff          0.048025
# dtype: float64

# %%
df_aapl_08.corrwith(df_msft_08['AdjClose'])
# Out:
# Open          0.729225
# High          0.734778
# Low           0.721659
# Close         0.729189
# Volume        0.037827
# ExDividend         NaN
# SplitRatio         NaN
# AdjOpen       0.729225
# AdjHigh       0.734778
# AdjLow        0.721659
# AdjClose      0.729189
# AdjVolume     0.037827
# Diff          0.097720
# dtype: float64

# %%
df_aapl_09.corrwith(df_msft_09['AdjClose'])
# Out:
# Open          0.952207
# High          0.952554
# Low           0.951642
# Close         0.951789
# Volume       -0.380901
# ExDividend         NaN
# SplitRatio         NaN
# AdjOpen       0.952207
# AdjHigh       0.952554
# AdjLow        0.951642
# AdjClose      0.951789
# AdjVolume    -0.380901
# Diff          0.024017
# dtype: float64

# %%
df_aapl_10.corrwith(df_msft_10['AdjClose'])
# Out:
# Open         -0.346012
# High         -0.352677
# Low          -0.340862
# Close        -0.342408
# Volume       -0.005194
# ExDividend         NaN
# SplitRatio         NaN
# AdjOpen      -0.346012
# AdjHigh      -0.352677
# AdjLow       -0.340862
# AdjClose     -0.342408
# AdjVolume    -0.005194
# Diff          0.055284
# dtype: float64

# %%
df_aapl_11.corrwith(df_msft_11['AdjClose'])
# Out:
# Open          0.311251
# High          0.318956
# Low           0.334411
# Close         0.345106
# Volume        0.095655
# ExDividend         NaN
# SplitRatio         NaN
# AdjOpen       0.311251
# AdjHigh       0.318956
# AdjLow        0.334411
# AdjClose      0.345106
# AdjVolume     0.095655
# Diff          0.014463
# dtype: float64

# %%
df_aapl_12.corrwith(df_msft_12['AdjClose'])
# Out:
# Open          0.439444
# High          0.440797
# Low           0.452120
# Close         0.452341
# Volume        0.133312
# ExDividend    0.003598
# SplitRatio         NaN
# AdjOpen       0.422742
# AdjHigh       0.423903
# AdjLow        0.435539
# AdjClose      0.435566
# AdjVolume     0.133312
# Diff         -0.054641
# dtype: float64

# %%
df_aapl_13.corrwith(df_msft_13['AdjClose'])
# Out:
# Open          0.411249
# High          0.414554
# Low           0.430208
# Close         0.427862
# Volume       -0.438830
# ExDividend    0.011591
# SplitRatio         NaN
# AdjOpen       0.462714
# AdjHigh       0.466691
# AdjLow        0.479532
# AdjClose      0.478085
# AdjVolume    -0.438830
# Diff         -0.120706
# dtype: float64

# %%
df_aapl_14.corrwith(df_msft_14['AdjClose'])
# Out:
# Open         -0.813747
# High         -0.813807
# Low          -0.813279
# Close        -0.813068
# Volume        0.656510
# ExDividend   -0.091327
# SplitRatio   -0.017990
# AdjOpen       0.944733
# AdjHigh       0.944874
# AdjLow        0.945636
# AdjClose      0.946171
# AdjVolume    -0.408253
# Diff         -0.015649
# dtype: float64

# %%
df_aapl_15.corrwith(df_msft_15['AdjClose'])
# Out:
# Open         -0.289729
# High         -0.309110
# Low          -0.273783
# Close        -0.292371
# Volume       -0.236856
# ExDividend    0.022255
# SplitRatio         NaN
# AdjOpen      -0.239364
# AdjHigh      -0.257582
# AdjLow       -0.224644
# AdjClose     -0.242071
# AdjVolume    -0.236856
# Diff          0.142586
# dtype: float64

# %%
df_aapl_16.corrwith(df_msft_16['AdjClose'])
# Out:
# Open          0.865017
# High          0.866391
# Low           0.872031
# Close         0.871872
# Volume       -0.311154
# ExDividend   -0.022520
# SplitRatio         NaN
# AdjOpen       0.886999
# AdjHigh       0.888944
# AdjLow        0.892266
# AdjClose      0.892983
# AdjVolume    -0.311154
# Diff          0.007188
# dtype: float64

# %%
df_aapl_17.corrwith(df_msft_17['AdjClose'])
# Out:
# Open          0.908193
# High          0.911170
# Low           0.910859
# Close         0.913481
# Volume        0.010297
# ExDividend   -0.062771
# SplitRatio         NaN
# AdjOpen       0.910752
# AdjHigh       0.913645
# AdjLow        0.913480
# AdjClose      0.915984
# AdjVolume     0.010297
# Diff          0.064148
# dtype: float64

# %%
df_aapl_07_AdjClose = df_aapl_07['AdjClose']
df_aapl_07_AdjClose.head()
# Out:
# Date
# 2007-12-31    25.456041
# 2007-12-28    25.680940
# 2007-12-27    25.519013
# 2007-12-26    25.567848
# 2007-12-24    25.548571
# Name: AdjClose, dtype: float64

# %%
df_msft_07_AdjClose = df_msft_07['AdjClose']
df_msft_07_AdjClose.head()
# Out:
# Date
# 2007-12-31    27.754531
# 2007-12-28    28.159934
# 2007-12-27    28.042991
# 2007-12-26    28.541949
# 2007-12-24    28.518560
# Name: AdjClose, dtype: float64

# %%
df_aapl_07_AdjClose.rename(index='Date')
df_aapl_07_AdjClose.to_frame()
df_aapl_07_AdjClose.head()
# Out:
# Date
# 2007-12-31    25.456041
# 2007-12-28    25.680940
# 2007-12-27    25.519013
# 2007-12-26    25.567848
# 2007-12-24    25.548571
# Name: AdjClose, dtype: float64

# %%
df_msft_07_AdjClose.rename(index='Date')
df_msft_07_AdjClose.head()
# Out:
# Date
# 2007-12-31    27.754531
# 2007-12-28    28.159934
# 2007-12-27    28.042991
# 2007-12-26    28.541949
# 2007-12-24    28.518560
# Name: AdjClose, dtype: float64

# %%
merged_07 = pd.concat([df_aapl_07_AdjClose, df_msft_07_AdjClose], axis=1, join_axes=[df_aapl_07_AdjClose.index])
merged_07.columns = ['AAPL_07', 'MSFT_07']
merged_07.head()
# Out:
#               AAPL_07    MSFT_07
# Date
# 2007-12-31  25.456041  27.754531
# 2007-12-28  25.680940  28.159934
# 2007-12-27  25.519013  28.042991
# 2007-12-26  25.567848  28.541949
# 2007-12-24  25.548571  28.518560

# %%
correlation = merged_07.corr()
correlation
# Out:
#           AAPL_07   MSFT_07
# AAPL_07  1.000000  0.761669
# MSFT_07  0.761669  1.000000

# %%
seb.regplot(df_aapl_07['Diff'], df_msft_07['Diff'], marker = 'x')

# %%
seb.regplot(df_aapl_08['Diff'], df_msft_08['Diff'], marker = 'x')

# %%
seb.regplot(df_aapl_09['Diff'], df_msft_09['Diff'], marker = 'x')

# %%
seb.regplot(df_aapl_10['Diff'], df_msft_10['Diff'], marker = 'x')

# %%
df_aapl_11['Apple Average Close Differential']=df_aapl_11['Diff']
df_msft_11['Microsoft Average Close Differential']=df_msft_11['Diff']
seb.regplot(df_aapl_11['Apple Average Close Differential'], df_msft_11['Microsoft Average Close Differential'], marker = 'x')
plt.title('AAPL & MSFt 11')
plt.savefig('Higest regression AM')

# %%
seb.regplot(df_aapl_12['Diff'], df_msft_12['Diff'], marker = 'x')

# %%
df_aapl_13['Apple Average Close Differential']=df_aapl_13['Diff']
df_msft_13['Microsoft Average Close Differential']=df_msft_13['Diff']
seb.regplot(df_aapl_13['Apple Average Close Differential'], df_msft_13['Microsoft Average Close Differential'], marker = 'x')
plt.title('AAPL & MSFt 13')
plt.savefig('Lowest regression AM')

# %%
seb.regplot(df_aapl_14['Diff'], df_msft_14['Diff'], marker = 'x')

# %%
seb.regplot(df_aapl_15['Diff'], df_msft_15['Diff'], marker = 'x')

# %%
seb.regplot(df_aapl_16['Diff'], df_msft_16['Diff'], marker = 'x')

# %%
seb.regplot(df_aapl_17['Diff'], df_msft_17['Diff'], marker = 'x')

# %%
df_aapl_07.loc[:,"Diff"].std()
df_aapl_08.loc[:,"Diff"].std()
df_aapl_09.loc[:,"Diff"].std()
df_aapl_10.loc[:,"Diff"].std()
df_aapl_11.loc[:,"Diff"].std()
df_aapl_12.loc[:,"Diff"].std()
df_aapl_13.loc[:,"Diff"].std()
df_aapl_14.loc[:,"Diff"].std()
df_aapl_15.loc[:,"Diff"].std()
df_aapl_16.loc[:,"Diff"].std()
df_aapl_17.loc[:,"Diff"].std()

df_msft_07.loc[:,"Diff"].std()
df_msft_08.loc[:,"Diff"].std()
df_msft_09.loc[:,"Diff"].std()
df_msft_10.loc[:,"Diff"].std()
df_msft_11.loc[:,"Diff"].std()
df_msft_12.loc[:,"Diff"].std()
df_msft_13.loc[:,"Diff"].std()
df_msft_14.loc[:,"Diff"].std()
df_msft_15.loc[:,"Diff"].std()
df_msft_16.loc[:,"Diff"].std()
df_msft_17.loc[:,"Diff"].std()
# Out:
# 0.6918489209615737

# %%
df_aapl_07.loc[:,"Diff"].cov(df_msft_07.loc[:,"Diff"])
# Out:
# 0.0670293058661741

# %%
df_aapl_08.loc[:,"Diff"].cov(df_msft_08.loc[:,"Diff"])
# Out:
# 0.20450743745830824

# %%
df_aapl_09.loc[:,"Diff"].cov(df_msft_09.loc[:,"Diff"])
# Out:
# 0.050728526561584726

# %%
df_aapl_10.loc[:,"Diff"].cov(df_msft_10.loc[:,"Diff"])
# Out:
# 0.09409668150610685

# %%
df_aapl_11.loc[:,"Diff"].cov(df_msft_11.loc[:,"Diff"])
# Out:
# 0.1460550809487109

# %%
df_aapl_12.loc[:,"Diff"].cov(df_msft_12.loc[:,"Diff"])
# Out:
# 0.12576681280587734

# %%
df_aapl_13.loc[:,"Diff"].cov(df_msft_13.loc[:,"Diff"])
# Out:
# 0.03605557971132576

# %%
df_aapl_14.loc[:,"Diff"].cov(df_msft_14.loc[:,"Diff"])
# Out:
# 0.14019798519683654

# %%
df_aapl_15.loc[:,"Diff"].cov(df_msft_15.loc[:,"Diff"])
# Out:
# 0.7582772073255254

# %%
df_aapl_16.loc[:,"Diff"].cov(df_msft_16.loc[:,"Diff"])
# Out:
# 0.5259302414324757

# %%
df_aapl_17.loc[:,"Diff"].cov(df_msft_17.loc[:,"Diff"])
# Out:
# 0.5250676392336358

# %%
aapl_07_mean=df_aapl_07['Diff'].mean()
aapl_07_mean
# Out:
# -0.05874629117882

# %%
aapl_08_mean=df_aapl_08['Diff'].mean()
aapl_08_mean
# Out:
# 0.05583726600539285

# %%
aapl_09_mean=df_aapl_09['Diff'].mean()
aapl_09_mean
# Out:
# -0.061431710227844605

# %%
aapl_10_mean=df_aapl_10['Diff'].mean()
aapl_10_mean
# Out:
# -0.05557843797596813

# %%
aapl_11_mean=df_aapl_11['Diff'].mean()
aapl_11_mean
# Out:
# -0.03862074229872907

# %%
aapl_12_mean=df_aapl_12['Diff'].mean()
aapl_12_mean
# Out:
# -0.06490364702983135

# %%
aapl_13_mean=df_aapl_13['Diff'].mean()
aapl_13_mean
# Out:
# -0.013451928329549766

# %%
aapl_14_mean=df_aapl_14['Diff'].mean()
aapl_14_mean
# Out:
# -0.1248527424291952

# %%
aapl_15_mean=df_aapl_15['Diff'].mean()
aapl_15_mean
# Out:
# 0.008634052766414341

# %%
aapl_16_mean=df_aapl_16['Diff'].mean()
aapl_16_mean
# Out:
# -0.05022187412944234

# %%
aapl_17_mean=df_aapl_17['Diff'].mean()
aapl_17_mean
# Out:
# -0.2198170249938709

# %%
msft_07_mean=df_msft_07['Diff'].mean()
aapl_07_mean
# Out:
# -0.05874629117882

# %%
msft_08_mean=df_msft_08['Diff'].mean()
msft_08_mean
# Out:
# 0.04771415588460318

# %%
msft_09_mean=df_msft_09['Diff'].mean()
msft_09_mean
# Out:
# -0.03438477143411155

# %%
msft_10_mean=df_msft_10['Diff'].mean()
msft_10_mean
# Out:
# 0.007968026377111552

# %%
msft_11_mean=df_msft_11['Diff'].mean()
msft_11_mean
# Out:
# 0.004401720543235059

# %%
msft_12_mean=df_msft_12['Diff'].mean()
msft_12_mean
# Out:
# -0.0024290254723011995

# %%
msft_13_mean=df_msft_13['Diff'].mean()
msft_13_mean
# Out:
# -0.038103262979334654

# %%
msft_14_mean=df_msft_14['Diff'].mean()
msft_14_mean
# Out:
# -0.037944850225175276

# %%
msft_15_mean=df_msft_15['Diff'].mean()
msft_15_mean
# Out:
# -0.037788025484533895

# %%
msft_16_mean=df_msft_16['Diff'].mean()
msft_16_mean
# Out:
# -0.03429128380367728

# %%
msft_17_mean=df_msft_17['Diff'].mean()
msft_17_mean
# Out:
# -0.09651160515631052

# %%
def gendata_07(loc1=0, loc2=0):
    population_n_07 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_07 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_07, population_a_07
population_n_07, population_a_07 = gendata_07(loc1=aapl_07_mean, loc2=msft_07_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_07)), population_n_07, label="AAPL 07")
plt.scatter(range(len(population_a_07)), population_a_07, label="MSFT 07")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_07, 10, density=True, alpha=0.5, label="AAPL 07")
plt.hist(population_a_07, 10, density=True, alpha=0.5, label="MSFT 07")
plt.axvline(population_n_07.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_07.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_07, population_a_07, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.4330441282437763, pvalue=0.6651702014272423)

# %%
def gendata_08(loc1=0, loc2=0):
    population_n_08 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_08 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_08, population_a_08
population_n_08, population_a_08 = gendata_07(loc1=aapl_08_mean, loc2=msft_08_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_08)), population_n_08, label="AAPL 08")
plt.scatter(range(len(population_a_08)), population_a_08, label="MSFT 08")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_08, 10, density=True, alpha=0.5, label="AAPL 08")
plt.hist(population_a_08, 10, density=True, alpha=0.5, label="MSFT 08")
plt.axvline(population_n_08.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_08.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_08, population_a_08, equal_var=False)
# Out:
# Ttest_indResult(statistic=0.08881285434203313, pvalue=0.9292663457061)

# %%
def gendata_09(loc1=0, loc2=0):
    population_n_09 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_09 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_09, population_a_09
population_n_09, population_a_09 = gendata_09(loc1=aapl_09_mean, loc2=msft_09_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_09)), population_n_09, label="AAPL 09")
plt.scatter(range(len(population_a_09)), population_a_09, label="MSFT 09")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_09, 10, density=True, alpha=0.5, label="AAPL 09")
plt.hist(population_a_09, 10, density=True, alpha=0.5, label="MSFT 09")
plt.axvline(population_n_09.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_09.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_09, population_a_09, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.29571380909116474, pvalue=0.7675719111754925)

# %%
def gendata_10(loc1=0, loc2=0):
    population_n_10 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_10 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_10, population_a_10
population_n_10, population_a_10 = gendata_10(loc1=aapl_10_mean, loc2=msft_10_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_10)), population_n_10, label="AAPL 10")
plt.scatter(range(len(population_a_10)), population_a_10, label="MSFT 10")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_10, 10, density=True, alpha=0.5, label="AAPL 10")
plt.hist(population_a_10, 10, density=True, alpha=0.5, label="MSFT 10")
plt.axvline(population_n_10.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_10.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_10, population_a_10, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.6947761139045874, pvalue=0.48751963701706147)

# %%
def gendata_11(loc1=0, loc2=0):
    population_n_11 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_11 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_11, population_a_11
population_n_11, population_a_11 = gendata_11(loc1=aapl_11_mean, loc2=msft_11_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_07)), population_n_07, label="AAPL 11")
plt.scatter(range(len(population_a_07)), population_a_07, label="MSFT 11")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_11, 10, density=True, alpha=0.5, label="AAPL 11")
plt.hist(population_a_11, 10, density=True, alpha=0.5, label="MSFT 11")
plt.axvline(population_n_11.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_11.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_11, population_a_11, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.47037989994002993, pvalue=0.6382895567671489)

# %%
def gendata_12(loc1=0, loc2=0):
    population_n_12 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_12 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_12, population_a_12
population_n_12, population_a_12 = gendata_12(loc1=aapl_12_mean, loc2=msft_12_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_07)), population_n_12, label="AAPL 12")
plt.scatter(range(len(population_a_07)), population_a_12, label="MSFT 12")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_12, 10, density=True, alpha=0.5, label="AAPL 12")
plt.hist(population_a_12, 10, density=True, alpha=0.5, label="MSFT 12")
plt.axvline(population_n_12.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_12.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_12, population_a_12, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.6830572751023083, pvalue=0.4948882902973031)

# %%
def gendata_13(loc1=0, loc2=0):
    population_n_13 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_13 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_13, population_a_13
population_n_13, population_a_13 = gendata_13(loc1=aapl_13_mean, loc2=msft_13_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_13)), population_n_13, label="AAPL 13")
plt.scatter(range(len(population_a_13)), population_a_13, label="MSFT 13")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_13, 10, density=True, alpha=0.5, label="AAPL 13")
plt.hist(population_a_13, 10, density=True, alpha=0.5, label="MSFT 13")
plt.axvline(population_n_13.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_13.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_13, population_a_13, equal_var=False)
# Out:
# Ttest_indResult(statistic=0.26952181627881605, pvalue=0.7876397936649429)

# %%
def gendata_14(loc1=0, loc2=0):
    population_n_14 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_14 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_14, population_a_14
population_n_14, population_a_14 = gendata_14(loc1=aapl_14_mean, loc2=msft_14_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_14)), population_n_14, label="AAPL 14")
plt.scatter(range(len(population_a_14)), population_a_14, label="MSFT 14")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_14, 10, density=True, alpha=0.5, label="AAPL 14")
plt.hist(population_a_14, 10, density=True, alpha=0.5, label="MSFT 14")
plt.axvline(population_n_14.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_14.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_14, population_a_14, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.9501949200140108, pvalue=0.34247411906387126)

# %%
def gendata_15(loc1=0, loc2=0):
    population_n_15 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_15 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_15, population_a_15
population_n_15, population_a_15 = gendata_15(loc1=aapl_15_mean, loc2=msft_15_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_15)), population_n_15, label="AAPL 15")
plt.scatter(range(len(population_a_15)), population_a_15, label="MSFT 15")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_15, 10, density=True, alpha=0.5, label="AAPL 15")
plt.hist(population_a_15, 10, density=True, alpha=0.5, label="MSFT 15")
plt.axvline(population_n_15.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_15.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(population_n_15, population_a_15, equal_var=False)
# Out:
# Ttest_indResult(statistic=0.507549105287168, pvalue=0.6119942885109984)

# %%
def gendata_16(loc1=0, loc2=0):
    population_n_16 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_16 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_16, population_a_16
population_n_16, population_a_16 = gendata_16(loc1=aapl_16_mean, loc2=msft_16_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_16)), population_n_16, label="AAPL 16")
plt.scatter(range(len(population_a_16)), population_a_16, label="MSFT 16")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_16, 10, density=True, alpha=0.5, label="AAPL 16")
plt.hist(population_a_16, 10, density=True, alpha=0.5, label="MSFT 16")
plt.axvline(population_n_16.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_16.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend() 
plt.savefig('AM Histogram 16')

# %%
stats.ttest_ind(population_n_16, population_a_16, equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.17417481446715, pvalue=0.861798859033389)

# %%
def gendata_17(loc1=0, loc2=0):
    population_n_17 = stats.norm.rvs(loc=loc1, size = 250, random_state=250)
    population_a_17 = stats.norm.rvs(loc=loc2, size = 250, random_state=250)
    return population_n_17, population_a_17
population_n_17, population_a_17 = gendata_17(loc1=aapl_17_mean, loc2=msft_17_mean)
plt.subplot(2, 1, 1)
plt.scatter(range(len(population_n_17)), population_n_17, label="AAPL 17")
plt.scatter(range(len(population_a_17)), population_a_17, label="MSFT 17")
plt.legend()

    # Histogram Plot of Data
plt.subplot(2, 1, 2)
plt.hist(population_n_17, 10, density=True, alpha=0.5, label="AAPL 17")
plt.hist(population_a_17, 10, density=True, alpha=0.5, label="MSFT 17")
plt.axvline(population_n_17.mean(), color='r', linestyle='dashed', linewidth=1)
plt.axvline(population_a_17.mean(), color='r', linestyle='dashed', linewidth=1)
plt.legend() 
plt.savefig('NA Histogram 17')

# %%
stats.ttest_ind(population_n_17, population_a_17, equal_var=False)
# Out:
# Ttest_indResult(statistic=-1.3481420451988055, pvalue=0.1782255644112726)

# %%
data1 = pd.DataFrame(df_aapl_07['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_07['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.224899
# 2         1   Diff -0.161928
# 3         1   Diff  0.048835
# 4         1   Diff -0.019277

# %%
data1 = pd.DataFrame(df_aapl_08['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_08['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.120803
# 2         1   Diff  0.041124
# 3         1   Diff -0.102811
# 4         1   Diff -0.098956

# %%
data1 = pd.DataFrame(df_aapl_09['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_09['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.116691
# 2         1   Diff -0.326425
# 3         1   Diff  0.322570
# 4         1   Diff -0.330281

# %%
data1 = pd.DataFrame(df_aapl_10['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_10['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.141365
# 2         1   Diff  0.209478
# 3         1   Diff  0.023133
# 4         1   Diff -0.101526

# %%
data1 = pd.DataFrame(df_aapl_11['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_11['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.015422
# 2         1   Diff -0.318715
# 3         1   Diff  0.499919
# 4         1   Diff -0.411245

# %%
data1 = pd.DataFrame(df_aapl_12['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_12['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff -2.928553
# 2         1   Diff  0.709429
# 3         1   Diff -0.267196
# 4         1   Diff  0.929579

# %%
data1 = pd.DataFrame(df_aapl_13['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_13['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff -0.863996
# 2         1   Diff  0.740378
# 3         1   Diff  0.506435
# 4         1   Diff  0.501118

# %%
data1 = pd.DataFrame(df_aapl_14['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_14['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  2.033009
# 2         1   Diff  1.320506
# 3         1   Diff  0.076000
# 4         1   Diff -1.881008

# %%
data1 = pd.DataFrame(df_aapl_15['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_15['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  1.990266
# 2         1   Diff  1.371931
# 3         1   Diff -1.855005
# 4         1   Diff  1.169040

# %%
data1 = pd.DataFrame(df_aapl_16['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_16['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter     value
# 0         1   Diff       NaN
# 1         1   Diff  0.898760
# 2         1   Diff  0.029629
# 3         1   Diff  0.493824
# 4         1   Diff -0.730860

# %%
data1 = pd.DataFrame(df_aapl_17['Diff']).assign(Location=1)
data2 = pd.DataFrame(df_msft_17['Diff']).assign(Location=2)

cdf = pd.concat([data1, data2])    
mdf = pd.melt(cdf, id_vars=['Location'], var_name=['Letter'])
print(mdf.head())
ax = seb.boxplot(x="Location", y="value", hue="Letter", data=mdf)    
plt.show()
# Out:
#    Location Letter  value
# 0         1   Diff    NaN
# 1         1   Diff   1.85
# 2         1   Diff  -0.48
# 3         1   Diff  -0.03
# 4         1   Diff   4.44
